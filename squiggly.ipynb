# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

from squiggly import SquigglyLine

# %%
x = np.arange(0, 20, 0.1)
y = np.sin(x)

# %%
line = SquigglyLine(x, y)
fig = line.plot()
