# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from datetime import datetime, timedelta

from squiggly import SquigglyLine

# %%
# x = np.arange(0, 20, 0.1)
# y = np.sin(x)

x = np.arange(datetime(1985,7,1), datetime(2015,7,1), timedelta(days=10)).astype(datetime)
y = np.sin([x.timestamp() * 10 / t[0].timestamp() for x in t])

# %%
SquigglyLine(x, y, 'Degree-of-Insult of a statement vs Time').plot()
