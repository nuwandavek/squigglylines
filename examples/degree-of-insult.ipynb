# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("../")

import numpy as np
from datetime import datetime, timedelta
from squiggly import SquigglyPlot

# %%
x = np.array([datetime(2015,1,1), datetime(2020,1,1), datetime(2020,1,2), datetime(2021,1,1), datetime(2022,1,1), datetime(2023,3,19)])
y = np.array([95, 90, -90, -10, 40, 70]) / 100


squigglyplot = SquigglyPlot(figsize=(20, 10))
squigglyplot.draw_line(x, y, noise_strength=0.2, c="r", label='"Are you still in the Bay Area?"')
squigglyplot.draw_grid([datetime(2015, 1, 1), datetime(2024,1,1)], [-1, 1], legend=True)
squigglyplot.draw_title('Degree-of-Insult of a statement vs Time')
